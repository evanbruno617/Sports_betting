# %%
import pandas as pd
import numpy as np

# %%
# read in team 1 data
data1 = pd.read_csv("Final_Score/LSTM/Boston Celtics.csv", index_col="Unnamed: 0")

# %%
# read in team 2 data
data2 = pd.read_csv("Final_Score/LSTM/Oklahoma City Thunder.csv", index_col="Unnamed: 0")

# %%
#create index with both datasets
new_index = data1.index.append(data2.index)

# %%
# append first teams stats
test = data1["0"].tolist()

# %%
# append second teams stats
for X in data2["0"].tolist():
    test.append(X)

# %%
# create datframe
nba_stats = pd.DataFrame(test)

# %%
# make column from index with names
nba_stats["Name"] = new_index

# %%
# rename column scores 
nba_stats.rename(columns={0: "scores"}, inplace=True)

# %%
nba_stats = nba_stats.dropna()

# %%
# obtain DKG salary file
DKG_salary = pd.read_csv("DKSalaries.csv")

# %%
DKG_salary
# Out:
#    Position                           Name + ID                     Name  \
# 0     SF/PF             Jayson Tatum (25322055)             Jayson Tatum
# 1        PG  Shai Gilgeous-Alexander (25322056)  Shai Gilgeous-Alexander
# 2     SG/SF             Jaylen Brown (25322057)             Jaylen Brown
# 3     SF/PF             Jayson Tatum (25322021)             Jayson Tatum
# 4     PG/SG              Josh Giddey (25322058)              Josh Giddey
# ..      ...                                 ...                      ...
# 63    SG/SF         Lindy Waters III (25322050)         Lindy Waters III
# 64    SG/SF           Justin Jackson (25322051)           Justin Jackson
# 65    PG/SG               JD Davison (25322052)               JD Davison
# 66       SG               Isaiah Joe (25322053)               Isaiah Joe
# 67        C            Chet Holmgren (25322054)            Chet Holmgren
#
#           ID Roster Position  Salary                      Game Info  \
# 0   25322055             CPT   18900  OKC@BOS 11/14/2022 07:30PM ET
# 1   25322056             CPT   15900  OKC@BOS 11/14/2022 07:30PM ET
# 2   25322057             CPT   15300  OKC@BOS 11/14/2022 07:30PM ET
# 3   25322021            UTIL   12600  OKC@BOS 11/14/2022 07:30PM ET
# 4   25322058             CPT   12000  OKC@BOS 11/14/2022 07:30PM ET
# ..       ...             ...     ...                            ...
# 63  25322050            UTIL    1000  OKC@BOS 11/14/2022 07:30PM ET
# 64  25322051            UTIL    1000  OKC@BOS 11/14/2022 07:30PM ET
# 65  25322052            UTIL    1000  OKC@BOS 11/14/2022 07:30PM ET
# 66  25322053            UTIL    1000  OKC@BOS 11/14/2022 07:30PM ET
# 67  25322054            UTIL    1000  OKC@BOS 11/14/2022 07:30PM ET
#
#    TeamAbbrev  AvgPointsPerGame
# 0         BOS             52.69
# 1         OKC             51.10
# 2         BOS             41.33
# 3         BOS             52.69
# 4         OKC             34.18
# ..        ...               ...
# 63        OKC              3.00
# 64        BOS              3.25
# 65        BOS              2.75
# 66        OKC              6.88
# 67        OKC              0.00
#
# [68 rows x 9 columns]

# %%
# salary for players
UTIL = DKG_salary.loc[DKG_salary["Roster Position"] == "UTIL",:]

# %%
# salary for captains
CPT = DKG_salary.loc[DKG_salary["Roster Position"] == "CPT"]

# %%
#creates alt scores with avg ppg provided by draftkings
alt_scores = DKG_salary["AvgPointsPerGame"]

# %%
# makes new name list
new_names = nba_stats["Name"].tolist()

# %%
dk_names = DKG_salary['Name']

names_drop = []

for name in dk_names:
    if name not in new_names:
        print(f"Not current: {name}")
        
        


for name in new_names:
    if name not in dk_names.tolist():
        print(f"Roster: {name}")
        names_drop.append(name)
# Out:
# Not current: Robert Williams
# Not current: Robert Williams
# Not current: Danilo Gallinari
# Not current: Mfiondu Kabengele
# Not current: Jaylin Williams
# Not current: Lindy Waters III
# Not current: Justin Jackson
# Not current: JD Davison
# Not current: Chet Holmgren
# Not current: Danilo Gallinari
# Not current: Mfiondu Kabengele
# Not current: Jaylin Williams
# Not current: Lindy Waters III
# Not current: Justin Jackson
# Not current: JD Davison
# Not current: Chet Holmgren

# %%
for replace in names_drop:
    nba_stats  = nba_stats.loc[nba_stats["Name"] != replace]

# %%
# iterates through UTIL to get salary
s = []
t = []
for x in nba_stats["Name"]:
    
    
    if x in dk_names.tolist():
        row = UTIL.loc[UTIL["Name"] == x]
        s.append(row["Salary"].values[0])
        t.append(row["AvgPointsPerGame"].values[0])

# %%
#makes column with salary
nba_stats["UTIL_salary"] = s

nba_stats["Alt_Salary"] = t

# %%
# gets CPT salary by 1.5 X UTIL
nba_stats["CPT_Salary"] = nba_stats["UTIL_salary"] * 1.5

# %%
drop_columns = nba_stats.sort_values(by="scores").head(10)["Name"].tolist()

# %%
name_list = nba_stats.sort_values(by="scores", ascending=False).head(22)["Name"].tolist()

# %%
# list of players to keep
name_list = ['Jayson Tatum',
 'Stephen Curry',
 'Jaylen Brown',
 'Al Horford',
 'Andrew Wiggins',
 'Klay Thompson',
 'Marcus Smart',
 'Draymond Green',
 'Jordan Poole',
 'Kevon Looney',
 'Derrick White', 
    'Gary Payton II',
            'Robert Williams']

# %%
# list of columns to drop 
drop_columns = [
 'Dennis Schroder',
 'Dwayne Bacon',
 'Jay Huff',
 'Juan Toscano-Anderson',
 'Kendrick Nunn',
'Lonnie Walker IV',
 'Matt Ryan',
 'Max Christie',
 'Patrick Beverley',
 'Russell Westbrook',
 'Scotty Pippen Jr.',
 'Thomas Bryant',
 'Wenyen Gabriel',
    'Patrick Baldwin Jr.',
    'Moses Moody',
    'Cole Swider',
 'Damian Jones',
    
]

# %%
nba_stats.sort_values(by = 'scores', ascending = False)
# Out:
#        scores                     Name  UTIL_salary  Alt_Salary  CPT_Salary
# 5   48.144436             Jaylen Brown        10200       41.33     15300.0
# 28  36.322121  Shai Gilgeous-Alexander        10600       51.10     15900.0
# 22  32.729527              Josh Giddey         8000       34.18     12000.0
# 10  29.990700             Marcus Smart         7600       28.15     11400.0
# 3   28.166260           Grant Williams         6800       21.50     10200.0
# 23  28.037525         Kenrich Williams         2000       15.42      3000.0
# 16  26.737101            Darius Bazley         4200       18.46      6300.0
# 6   26.725595             Jayson Tatum        12600       52.69     18900.0
# 15  24.586235       Aleksej Pokusevski         6200       22.98      9300.0
# 25  23.512005            Luguentz Dort         6000       26.27      9000.0
# 0   22.815506               Al Horford         7000       25.08     10500.0
# 17  22.349573           Eugene Omoruyi         2800       10.67      4200.0
# 9   20.998320          Malcolm Brogdon         6400       24.91      9600.0
# 13  19.643665               Sam Hauser         3200       12.77      4800.0
# 8   17.557364              Luke Kornet         1800       11.08      2700.0
# 21  15.367905   Jeremiah Robinson-Earl         1600       17.31      2400.0
# 18  12.971725               Isaiah Joe         1000        6.88      1500.0
# 29  12.606035                 Tre Mann         4600       20.69      6900.0
# 14  12.289583            Aaron Wiggins         4000       16.22      6000.0
# 11  10.771246              Noah Vonleh         2200        7.86      3300.0
# 1   10.521413            Blake Griffin         3000        9.58      4500.0
# 12  10.022891         Payton Pritchard         2600        8.46      3900.0
# 26   9.981009             Mike Muscala         1400       14.82      2100.0
# 2    8.215691            Derrick White         5800       20.19      8700.0
# 19   3.951120           Jalen Williams         4400       16.42      6600.0
# 27   3.397907            Ousmane Dieng         1000        9.39      1500.0

# %%
name_list = nba_stats.sort_values(by = 'scores', ascending = False).head(-4)["Name"].tolist()

# %%
drop_columns = nba_stats.sort_values(by = 'scores', ascending = False).tail(4)["Name"].tolist()

# %%
# Maually Remove name

name_list.remove("Malcolm Brogdon")

# %%
drop_columns.append("Malcolm Brogdon")

# %%
name_list = []
list_name = nba_stats["Name"]

for name in list_name:
    if name not in drop_columns:
        name_list.append(name)

# %%
index_drop = []
for i in drop_columns:
    row = nba_stats.loc[nba_stats["Name"] == i]
    index_drop.append(row.index[0])

# %%
for i in name_list:
    row = nba_stats.loc[nba_stats["Name"] == i]
    total_points = row["scores"]
    total_salary = 50000 - row["CPT_Salary"]

# %%
from itertools import combinations

# %%
from itertools import combinations
total_lists = []
temp_chosen = []

for i in name_list:
    row = nba_stats.loc[nba_stats["Name"] == i]
    score = row["scores"].tolist()[0] * 1.5
    max_salary = 50000 - row["CPT_Salary"].tolist()[0]

    comb = nba_stats.drop(index = index_drop)
    comb = nba_stats.dropna()
    comb = comb.sort_values("scores", ascending=False).copy()
    cpt_name = row["Name"].tolist()[0]
    print(cpt_name)
    print(score)
    temp_chosen.append({cpt_name : score})

    legit = ()
    max_score = 0

    comb = comb.drop(row.index)
    for combo in combinations(comb["Name"], 5):  # 2 for pairs, 3 for triplets, etc
        total_score = 0
        total_salary = 0
        for x in combo:
            rowP = nba_stats.loc[nba_stats["Name"] == x]
            total_score = total_score + rowP["scores"].tolist()[0]
            total_salary = total_salary + rowP["UTIL_salary"].tolist()[0]
        total_score = total_score + score
        if total_salary < max_salary:
            if total_score > max_score:
                team_salary = total_salary
                print(total_score)
                max_score = total_score
                legit = combo
                print(legit)
                
    temp_chosen.append({max_score : legit})
# Out:
# Al Horford
# 34.22325897216797
# 209.44756698608398
# ('Jaylen Brown', 'Shai Gilgeous-Alexander', 'Josh Giddey', 'Marcus Smart', 'Kenrich Williams')
# Blake Griffin
# 15.782119274139404
# 191.13516187667847
# ('Jaylen Brown', 'Shai Gilgeous-Alexander', 'Josh Giddey', 'Marcus Smart', 'Grant Williams')
# Grant Williams
# 42.2493896484375
# 217.47369766235352
# ('Jaylen Brown', 'Shai Gilgeous-Alexander', 'Josh Giddey', 'Marcus Smart', 'Kenrich Williams')
# Jaylen Brown
# 72.21665382385254
# 214.79316520690918
# ('Shai Gilgeous-Alexander', 'Josh Giddey', 'Marcus Smart', 'Grant Williams', 'Jeremiah Robinson-Earl')
# 226.03362655639648
# ('Shai Gilgeous-Alexander', 'Josh Giddey', 'Marcus Smart', 'Kenrich Williams', 'Darius Bazley')
# Jayson Tatum
# 40.088393211364746
# 173.65410780906677
# ('Jaylen Brown', 'Shai Gilgeous-Alexander', 'Josh Giddey', 'Isaiah Joe', 'Ousmane Dieng')
# 182.88527870178223
# ('Jaylen Brown', 'Shai Gilgeous-Alexander', 'Marcus Smart', 'Jeremiah Robinson-Earl', 'Isaiah Joe')
# 193.73045921325684
# ('Jaylen Brown', 'Shai Gilgeous-Alexander', 'Grant Williams', 'Kenrich Williams', 'Isaiah Joe')
# 201.67914867401123
# ('Jaylen Brown', 'Shai Gilgeous-Alexander', 'Kenrich Williams', 'Darius Bazley', 'Eugene Omoruyi')
# Luke Kornet
# 26.336045265197754
# 201.68908786773682
# ('Jaylen Brown', 'Shai Gilgeous-Alexander', 'Josh Giddey', 'Marcus Smart', 'Grant Williams')
# Marcus Smart
# 44.98604965209961
# 218.38591766357422
# ('Jaylen Brown', 'Shai Gilgeous-Alexander', 'Josh Giddey', 'Grant Williams', 'Kenrich Williams')
# Noah Vonleh
# 16.156868934631348
# 191.5099115371704
# ('Jaylen Brown', 'Shai Gilgeous-Alexander', 'Josh Giddey', 'Marcus Smart', 'Grant Williams')
# Payton Pritchard
# 15.034336566925049
# 190.3873791694641
# ('Jaylen Brown', 'Shai Gilgeous-Alexander', 'Josh Giddey', 'Marcus Smart', 'Grant Williams')
# Sam Hauser
# 29.465497970581055
# 204.81854057312012
# ('Jaylen Brown', 'Shai Gilgeous-Alexander', 'Josh Giddey', 'Marcus Smart', 'Grant Williams')
# Aaron Wiggins
# 18.434374809265137
# 193.7874174118042
# ('Jaylen Brown', 'Shai Gilgeous-Alexander', 'Josh Giddey', 'Marcus Smart', 'Grant Williams')
# Aleksej Pokusevski
# 36.87935256958008
# 212.1036605834961
# ('Jaylen Brown', 'Shai Gilgeous-Alexander', 'Josh Giddey', 'Marcus Smart', 'Kenrich Williams')
# Darius Bazley
# 40.105650901794434
# 215.4586935043335
# ('Jaylen Brown', 'Shai Gilgeous-Alexander', 'Josh Giddey', 'Marcus Smart', 'Grant Williams')
# Eugene Omoruyi
# 33.524359703063965
# 208.87740230560303
# ('Jaylen Brown', 'Shai Gilgeous-Alexander', 'Josh Giddey', 'Marcus Smart', 'Grant Williams')
# Isaiah Joe
# 19.45758676528931
# 194.81062936782837
# ('Jaylen Brown', 'Shai Gilgeous-Alexander', 'Josh Giddey', 'Marcus Smart', 'Grant Williams')
# Jeremiah Robinson-Earl
# 23.051856994628906
# 198.40489959716797
# ('Jaylen Brown', 'Shai Gilgeous-Alexander', 'Josh Giddey', 'Marcus Smart', 'Grant Williams')
# Josh Giddey
# 49.094289779663086
# 219.7553310394287
# ('Jaylen Brown', 'Shai Gilgeous-Alexander', 'Marcus Smart', 'Grant Williams', 'Kenrich Williams')
# Kenrich Williams
# 42.05628776550294
# 217.409330368042
# ('Jaylen Brown', 'Shai Gilgeous-Alexander', 'Josh Giddey', 'Marcus Smart', 'Grant Williams')
# Luguentz Dort
# 35.268007278442376
# 210.4923152923584
# ('Jaylen Brown', 'Shai Gilgeous-Alexander', 'Josh Giddey', 'Marcus Smart', 'Kenrich Williams')
# Shai Gilgeous-Alexander
# 54.483180999755874
# 206.4858274459839
# ('Jaylen Brown', 'Josh Giddey', 'Marcus Smart', 'Grant Williams', 'Isaiah Joe')
# 220.12246894836426
# ('Jaylen Brown', 'Josh Giddey', 'Marcus Smart', 'Kenrich Williams', 'Darius Bazley')
# Tre Mann
# 18.909052848815914
# 194.13336086273193
# ('Jaylen Brown', 'Shai Gilgeous-Alexander', 'Josh Giddey', 'Marcus Smart', 'Kenrich Williams')

# %%
temp_chosen
# Out:
# [{'Al Horford': 34.22325897216797},
#  {209.44756698608398: ('Jaylen Brown',
#    'Shai Gilgeous-Alexander',
#    'Josh Giddey',
#    'Marcus Smart',
#    'Kenrich Williams')},
#  {'Blake Griffin': 15.782119274139404},
#  {191.13516187667847: ('Jaylen Brown',
#    'Shai Gilgeous-Alexander',
#    'Josh Giddey',
#    'Marcus Smart',
#    'Grant Williams')},
#  {'Grant Williams': 42.2493896484375},
#  {217.47369766235352: ('Jaylen Brown',
#    'Shai Gilgeous-Alexander',
#    'Josh Giddey',
#    'Marcus Smart',
#    'Kenrich Williams')},
#  {'Jaylen Brown': 72.21665382385254},
#  {226.03362655639648: ('Shai Gilgeous-Alexander',
#    'Josh Giddey',
#    'Marcus Smart',
#    'Kenrich Williams',
#    'Darius Bazley')},
#  {'Jayson Tatum': 40.088393211364746},
#  {201.67914867401123: ('Jaylen Brown',
#    'Shai Gilgeous-Alexander',
#    'Kenrich Williams',
#    'Darius Bazley',
#    'Eugene Omoruyi')},
#  {'Luke Kornet': 26.336045265197754},
#  {201.68908786773682: ('Jaylen Brown',
#    'Shai Gilgeous-Alexander',
#    'Josh Giddey',
#    'Marcus Smart',
#    'Grant Williams')},
#  {'Marcus Smart': 44.98604965209961},
#  {218.38591766357422: ('Jaylen Brown',
#    'Shai Gilgeous-Alexander',
#    'Josh Giddey',
#    'Grant Williams',
#    'Kenrich Williams')},
#  {'Noah Vonleh': 16.156868934631348},
#  {191.5099115371704: ('Jaylen Brown',
#    'Shai Gilgeous-Alexander',
#    'Josh Giddey',
#    'Marcus Smart',
#    'Grant Williams')},
#  {'Payton Pritchard': 15.034336566925049},
#  {190.3873791694641: ('Jaylen Brown',
#    'Shai Gilgeous-Alexander',
#    'Josh Giddey',
#    'Marcus Smart',
#    'Grant Williams')},
#  {'Sam Hauser': 29.465497970581055},
#  {204.81854057312012: ('Jaylen Brown',
#    'Shai Gilgeous-Alexander',
#    'Josh Giddey',
#    'Marcus Smart',
#    'Grant Williams')},
#  {'Aaron Wiggins': 18.434374809265137},
#  {193.7874174118042: ('Jaylen Brown',
#    'Shai Gilgeous-Alexander',
#    'Josh Giddey',
#    'Marcus Smart',
#    'Grant Williams')},
#  {'Aleksej Pokusevski': 36.87935256958008},
#  {212.1036605834961: ('Jaylen Brown',
#    'Shai Gilgeous-Alexander',
#    'Josh Giddey',
#    'Marcus Smart',
#    'Kenrich Williams')},
#  {'Darius Bazley': 40.105650901794434},
#  {215.4586935043335: ('Jaylen Brown',
#    'Shai Gilgeous-Alexander',
#    'Josh Giddey',
#    'Marcus Smart',
#    'Grant Williams')},
#  {'Eugene Omoruyi': 33.524359703063965},
#  {208.87740230560303: ('Jaylen Brown',
#    'Shai Gilgeous-Alexander',
#    'Josh Giddey',
#    'Marcus Smart',
#    'Grant Williams')},
#  {'Isaiah Joe': 19.45758676528931},
#  {194.81062936782837: ('Jaylen Brown',
#    'Shai Gilgeous-Alexander',
#    'Josh Giddey',
#    'Marcus Smart',
#    'Grant Williams')},
#  {'Jeremiah Robinson-Earl': 23.051856994628906},
#  {198.40489959716797: ('Jaylen Brown',
#    'Shai Gilgeous-Alexander',
#    'Josh Giddey',
#    'Marcus Smart',
#    'Grant Williams')},
#  {'Josh Giddey': 49.094289779663086},
#  {219.7553310394287: ('Jaylen Brown',
#    'Shai Gilgeous-Alexander',
#    'Marcus Smart',
#    'Grant Williams',
#    'Kenrich Williams')},
#  {'Kenrich Williams': 42.05628776550294},
#  {217.409330368042: ('Jaylen Brown',
#    'Shai Gilgeous-Alexander',
#    'Josh Giddey',
#    'Marcus Smart',
#    'Grant Williams')},
#  {'Luguentz Dort': 35.268007278442376},
#  {210.4923152923584: ('Jaylen Brown',
#    'Shai Gilgeous-Alexander',
#    'Josh Giddey',
#    'Marcus Smart',
#    'Kenrich Williams')},
#  {'Shai Gilgeous-Alexander': 54.483180999755874},
#  {220.12246894836426: ('Jaylen Brown',
#    'Josh Giddey',
#    'Marcus Smart',
#    'Kenrich Williams',
#    'Darius Bazley')},
#  {'Tre Mann': 18.909052848815914},
#  {194.13336086273193: ('Jaylen Brown',
#    'Shai Gilgeous-Alexander',
#    'Josh Giddey',
#    'Marcus Smart',
#    'Kenrich Williams')}]

# %%
total_lists = []
alt_chosen = []

for i in name_list:
    row = nba_stats.loc[nba_stats["Name"] == i]
    score = row["Alt_Salary"].tolist()[0] * 1.5
    max_salary = 50000 - row["CPT_Salary"].tolist()[0]

    comb = nba_stats.drop(index = index_drop)
    comb = comb.sort_values("Alt_Salary", ascending=False).copy()
    cpt_name = row["Name"].tolist()[0]
    print(cpt_name)
    alt_chosen.append({cpt_name : score})

    legit = ()
    max_score = 0

    comb = comb.drop(row.index)
    for combo in combinations(comb["Name"], 5):  # 2 for pairs, 3 for triplets, etc
        total_score = 0
        total_salary = 0
        for x in combo:
            rowP = nba_stats.loc[nba_stats["Name"] == x]
            total_score = total_score + rowP["Alt_Salary"].tolist()[0]
            total_salary = total_salary + rowP["UTIL_salary"].tolist()[0]
        total_score = total_score + score
        if total_salary < max_salary:
            if total_score > max_score:
                team_salary = total_salary
                print(total_score)
                max_score = total_score
                legit = combo
                print(legit)
                
    alt_chosen.append({max_score : legit})
# Out:
# Andrew Wiggins
# 215.855
# ('Stephen Curry', 'Jimmy Butler', 'Tyler Herro', 'Draymond Green', 'Haywood Highsmith')
# 220.92499999999998
# ('Stephen Curry', 'Jimmy Butler', 'Tyler Herro', 'Caleb Martin', 'Duncan Robinson')
# Draymond Green
# 209.14
# ('Stephen Curry', 'Andrew Wiggins', 'Jimmy Butler', 'Tyler Herro', 'Haywood Highsmith')
# 212.48
# ('Stephen Curry', 'Andrew Wiggins', 'Jimmy Butler', 'Caleb Martin', 'James Wiseman')
# 216.69
# ('Stephen Curry', 'Andrew Wiggins', 'Tyler Herro', 'Max Strus', 'Caleb Martin')
# James Wiseman
# 214.67
# ('Stephen Curry', 'Andrew Wiggins', 'Jimmy Butler', 'Tyler Herro', 'Kevon Looney')
# Jordan Poole
# 210.535
# ('Stephen Curry', 'Andrew Wiggins', 'Jimmy Butler', 'Tyler Herro', 'Haywood Highsmith')
# 215.275
# ('Stephen Curry', 'Andrew Wiggins', 'Tyler Herro', 'Max Strus', 'James Wiseman')
# Kevon Looney
# 216.355
# ('Stephen Curry', 'Andrew Wiggins', 'Jimmy Butler', 'Tyler Herro', 'Caleb Martin')
# Moses Moody
# 210.31
# ('Stephen Curry', 'Andrew Wiggins', 'Jimmy Butler', 'Tyler Herro', 'Jordan Poole')
# Stephen Curry
# 217.1
# ('Andrew Wiggins', 'Jimmy Butler', 'Tyler Herro', 'Caleb Martin', 'Haywood Highsmith')
# 217.66
# ('Andrew Wiggins', 'Tyler Herro', 'Jordan Poole', 'Max Strus', 'Duncan Robinson')
# 218.26
# ('Andrew Wiggins', 'Tyler Herro', 'Draymond Green', 'James Wiseman', 'Kevon Looney')
# 221.84
# ('Andrew Wiggins', 'Tyler Herro', 'Max Strus', 'Caleb Martin', 'James Wiseman')
# Bam Adebayo
# 202.62
# ('Stephen Curry', 'Andrew Wiggins', 'Jimmy Butler', 'Max Strus', 'Haywood Highsmith')
# 205.78
# ('Stephen Curry', 'Andrew Wiggins', 'Jimmy Butler', 'James Wiseman', 'Moses Moody')
# 209.99
# ('Stephen Curry', 'Andrew Wiggins', 'Tyler Herro', 'Max Strus', 'Moses Moody')
# Caleb Martin
# 217.14499999999998
# ('Stephen Curry', 'Andrew Wiggins', 'Jimmy Butler', 'Tyler Herro', 'Gabe Vincent')
# Duncan Robinson
# 211.18
# ('Stephen Curry', 'Andrew Wiggins', 'Jimmy Butler', 'Tyler Herro', 'Jordan Poole')
# Gabe Vincent
# 213.745
# ('Stephen Curry', 'Andrew Wiggins', 'Jimmy Butler', 'Tyler Herro', 'Caleb Martin')
# Haywood Highsmith
# 200.82
# ('Stephen Curry', 'Andrew Wiggins', 'Jimmy Butler', 'Tyler Herro', 'Bam Adebayo')
# Jimmy Butler
# 213.27
# ('Stephen Curry', 'Andrew Wiggins', 'Tyler Herro', 'Max Strus', 'Haywood Highsmith')
# 216.43
# ('Stephen Curry', 'Andrew Wiggins', 'Tyler Herro', 'James Wiseman', 'Moses Moody')
# Kyle Lowry
# 208.87
# ('Stephen Curry', 'Andrew Wiggins', 'Jimmy Butler', 'Tyler Herro', 'Haywood Highsmith')
# 209.95999999999998
# ('Stephen Curry', 'Andrew Wiggins', 'Jimmy Butler', 'Caleb Martin', 'Kevon Looney')
# 216.42000000000002
# ('Stephen Curry', 'Andrew Wiggins', 'Tyler Herro', 'Max Strus', 'Caleb Martin')
# Max Strus
# 215.61999999999998
# ('Stephen Curry', 'Andrew Wiggins', 'Jimmy Butler', 'Tyler Herro', 'Duncan Robinson')
# 216.88
# ('Stephen Curry', 'Andrew Wiggins', 'Tyler Herro', 'Jordan Poole', 'Caleb Martin')
# Tyler Herro
# 214.375
# ('Stephen Curry', 'Andrew Wiggins', 'Jimmy Butler', 'Draymond Green', 'Haywood Highsmith')
# 218.865
# ('Stephen Curry', 'Andrew Wiggins', 'Jimmy Butler', 'Caleb Martin', 'Moses Moody')
# 219.115
# ('Stephen Curry', 'Andrew Wiggins', 'Draymond Green', 'Max Strus', 'James Wiseman')

# %%
alt_chosen
# Out:
# [{'Andrew Wiggins': 60.465},
#  {220.92499999999998: ('Stephen Curry',
#    'Jimmy Butler',
#    'Tyler Herro',
#    'Caleb Martin',
#    'Duncan Robinson')},
#  {'Draymond Green': 40.32},
#  {216.69: ('Stephen Curry',
#    'Andrew Wiggins',
#    'Tyler Herro',
#    'Max Strus',
#    'Caleb Martin')},
#  {'James Wiseman': 30.660000000000004},
#  {214.67: ('Stephen Curry',
#    'Andrew Wiggins',
#    'Jimmy Butler',
#    'Tyler Herro',
#    'Kevon Looney')},
#  {'Jordan Poole': 41.714999999999996},
#  {215.275: ('Stephen Curry',
#    'Andrew Wiggins',
#    'Tyler Herro',
#    'Max Strus',
#    'James Wiseman')},
#  {'Kevon Looney': 27.285000000000004},
#  {216.355: ('Stephen Curry',
#    'Andrew Wiggins',
#    'Jimmy Butler',
#    'Tyler Herro',
#    'Caleb Martin')},
#  {'Moses Moody': 16.68},
#  {210.31: ('Stephen Curry',
#    'Andrew Wiggins',
#    'Jimmy Butler',
#    'Tyler Herro',
#    'Jordan Poole')},
#  {'Stephen Curry': 75.09},
#  {221.84: ('Andrew Wiggins',
#    'Tyler Herro',
#    'Max Strus',
#    'Caleb Martin',
#    'James Wiseman')},
#  {'Bam Adebayo': 45.75},
#  {209.99: ('Stephen Curry',
#    'Andrew Wiggins',
#    'Tyler Herro',
#    'Max Strus',
#    'Moses Moody')},
#  {'Caleb Martin': 34.875},
#  {217.14499999999998: ('Stephen Curry',
#    'Andrew Wiggins',
#    'Jimmy Butler',
#    'Tyler Herro',
#    'Gabe Vincent')},
#  {'Duncan Robinson': 17.549999999999997},
#  {211.18: ('Stephen Curry',
#    'Andrew Wiggins',
#    'Jimmy Butler',
#    'Tyler Herro',
#    'Jordan Poole')},
#  {'Gabe Vincent': 24.674999999999997},
#  {213.745: ('Stephen Curry',
#    'Andrew Wiggins',
#    'Jimmy Butler',
#    'Tyler Herro',
#    'Caleb Martin')},
#  {'Haywood Highsmith': 4.5},
#  {200.82: ('Stephen Curry',
#    'Andrew Wiggins',
#    'Jimmy Butler',
#    'Tyler Herro',
#    'Bam Adebayo')},
#  {'Jimmy Butler': 57.150000000000006},
#  {216.43: ('Stephen Curry',
#    'Andrew Wiggins',
#    'Tyler Herro',
#    'James Wiseman',
#    'Moses Moody')},
#  {'Kyle Lowry': 40.05},
#  {216.42000000000002: ('Stephen Curry',
#    'Andrew Wiggins',
#    'Tyler Herro',
#    'Max Strus',
#    'Caleb Martin')},
#  {'Max Strus': 38.099999999999994},
#  {216.88: ('Stephen Curry',
#    'Andrew Wiggins',
#    'Tyler Herro',
#    'Jordan Poole',
#    'Caleb Martin')},
#  {'Tyler Herro': 56.025000000000006},
#  {219.115: ('Stephen Curry',
#    'Andrew Wiggins',
#    'Draymond Green',
#    'Max Strus',
#    'James Wiseman')}]
