# %%
import pandas as pd

# %%
date = input("Date")
team = input("Team")
# Out:
# Date2022-06-10 00:00:00
# TeamBoston

# %%
pred = pd.read_csv(f"Final_Score/LSTM/Backtesting/{team}/{team}_{date}.csv", index_col=0)
pred
# Out:
#                              0
# Aaron Nesmith         4.883414
# Al Horford           29.192957
# Daniel Theis         22.676270
# Derrick White         9.558358
# Grant Williams       24.208330
# Jaylen Brown         38.859707
# Jayson Tatum         40.154156
# Juwan Morgan          0.337428
# Luke Kornet          -0.025873
# Malik Fitts          -2.610331
# Marcus Smart         31.236488
# Nik Stauskas          0.377910
# Payton Pritchard     11.246497
# Robert Williams III  24.448553
# Sam Hauser           -0.004159

# %%
date = "2022-06-10"

# %%
test = pd.read_csv("Final_Score/Tables/Boston_Celtics.csv", index_col=0)
test
# Out:
#             Aaron Nesmith  Al Horford  Daniel Theis  Derrick White  \
# 06/16/2022           0.00       46.00           NaN           5.75
# 06/02/2022           0.00       42.00          5.50          28.25
# 06/10/2022            NaN       24.00           NaN          20.75
# 06/05/2022          11.50       14.50          9.25          25.50
# 06/13/2022           4.25       21.75           NaN           8.75
# 04/17/2022            NaN       44.25         13.00          22.25
# 05/25/2022           0.00       38.25           NaN          27.25
# 05/19/2022           1.25       21.75          4.75            NaN
# 05/27/2022           0.00       20.75           NaN          43.25
# 05/23/2022          10.25       34.25          7.75          39.00
# 05/21/2022           0.00       48.00          5.25           8.00
# 05/09/2022            NaN       48.50          2.25          23.00
# 05/11/2022            NaN       34.50         14.75          28.25
# ...

# %%
test.loc[test["Datetime"] == date]
# Out:
#             Aaron Nesmith  Al Horford  Daniel Theis  Derrick White  \
# 06/10/2022            NaN        24.0           NaN          20.75
#
#             Grant Williams  Jaylen Brown  Jayson Tatum  Juwan Morgan  \
# 06/10/2022            4.75          33.5         52.75           NaN
#
#             Luke Kornet  Malik Fitts  Marcus Smart  Nik Stauskas  \
# 06/10/2022          NaN          NaN          39.0           NaN
#
#             Payton Pritchard  Robert Williams III  Sam Hauser  \
# 06/10/2022              1.75                 34.0         NaN
#
#                                 0    Datetime
# 06/10/2022  Golden State Warriors  2022-06-10

# %%
pred
# Out:
#                              0
# Aaron Nesmith         4.883414
# Al Horford           29.192957
# Daniel Theis         22.676270
# Derrick White         9.558358
# Grant Williams       24.208330
# Jaylen Brown         38.859707
# Jayson Tatum         40.154156
# Juwan Morgan          0.337428
# Luke Kornet          -0.025873
# Malik Fitts          -2.610331
# Marcus Smart         31.236488
# Nik Stauskas          0.377910
# Payton Pritchard     11.246497
# Robert Williams III  24.448553
# Sam Hauser           -0.004159
