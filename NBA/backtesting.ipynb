# %%
import pandas as pd

# %%
# read in team 1 data
data1 = pd.read_csv("Final_Score/LSTM/BostonCeltics.csv", index_col="Unnamed: 0")

# %%
# read in team 2 data
data2 = pd.read_csv("Final_Score/BostonCeltics.csv", index_col="Unnamed: 0")

# %%
data1
# Out:
#                                0
# Andre Iguodala         -1.541667
# Andrew Wiggins         38.518182
# Damion Lee             -1.840571
# Draymond Green         23.354545
# Gary Payton II         27.375000
# Jonathan Kuminga       -3.160112
# Jordan Poole           17.672727
# Juan Toscano-Anderson   1.168103
# Kevon Looney           16.740909
# Klay Thompson          27.777273
# Moses Moody             0.857661
# Nemanja Bjelica         5.162441
# Otto Porter Jr.         7.009434
# Stephen Curry          47.072727

# %%
#create index with both datasets
new_index = data1.index.append(data2.index)

# %%
# append first teams stats
test = data1["0"].tolist()

# %%
test
# Out:
# [-1.541666666666668,
#  38.518181818181816,
#  -1.8405707196029777,
#  23.35454545454545,
#  27.375000000000007,
#  -3.16011235955056,
#  17.672727272727272,
#  1.168103448275862,
#  16.740909090909096,
#  27.777272727272724,
#  0.8576612903225813,
#  5.162441037735848,
#  7.009433962264151,
#  47.07272727272727]

# %%
# append second teams stats
for X in data2["0"].tolist():
    test.append(X)

# %%
test
# Out:
# [-1.541666666666668,
#  38.518181818181816,
#  -1.8405707196029777,
#  23.35454545454545,
#  27.375000000000007,
#  -3.16011235955056,
#  17.672727272727272,
#  1.168103448275862,
#  16.740909090909096,
#  27.777272727272724,
#  0.8576612903225813,
#  5.162441037735848,
#  7.009433962264151,
#  47.07272727272727,
#  4.820481927710844,
#  23.668181818181814,
#  9.414948453608249,
#  15.583333333333332,
#  6.704545454545452,
#  36.16818181818181,
#  51.60454545454546,
#  0.1592809364548492,
#  4.322033898305084,
#  1.9538152610441768,
#  26.02497502497502,
#  0.4602040816326527,
#  1.0090909090909062,
#  26.450757575757574,
#  1.4857142857142858]

# %%
# create datframe
nba_stats = pd.DataFrame(test)

# %%
# make column from index with names
nba_stats["Name"] = new_index

# %%
# rename column scores 
nba_stats.rename(columns={0: "scores"}, inplace=True)

# %%
nba_stats
# Out:
#        scores                   Name
# 0   -1.541667         Andre Iguodala
# 1   38.518182         Andrew Wiggins
# 2   -1.840571             Damion Lee
# 3   23.354545         Draymond Green
# 4   27.375000         Gary Payton II
# 5   -3.160112       Jonathan Kuminga
# 6   17.672727           Jordan Poole
# 7    1.168103  Juan Toscano-Anderson
# 8   16.740909           Kevon Looney
# 9   27.777273          Klay Thompson
# 10   0.857661            Moses Moody
# 11   5.162441        Nemanja Bjelica
# 12   7.009434        Otto Porter Jr.
# 13  47.072727          Stephen Curry
# 14   4.820482          Aaron Nesmith
# 15  23.668182             Al Horford
# 16   9.414948           Daniel Theis
# 17  15.583333          Derrick White
# 18   6.704545         Grant Williams
# 19  36.168182           Jaylen Brown
# 20  51.604545           Jayson Tatum
# 21   0.159281           Juwan Morgan
# 22   4.322034            Luke Kornet
# 23   1.953815            Malik Fitts
# 24  26.024975           Marcus Smart
# 25   0.460204           Nik Stauskas
# 26   1.009091       Payton Pritchard
# 27  26.450758    Robert Williams III
# 28   1.485714             Sam Hauser

# %%
# obtain DKG salary file
DKG_salary = pd.read_csv("game6.csv")

# %%
DKG_salary
# Out:
#    Position                         Name + ID                   Name  \
# 0        PG          Stephen Curry (23058778)          Stephen Curry
# 1     SF/PF           Jayson Tatum (23058779)           Jayson Tatum
# 2     SG/SF           Jaylen Brown (23058780)           Jaylen Brown
# 3     SF/PF         Andrew Wiggins (23058781)         Andrew Wiggins
# 4        PG           Marcus Smart (23058782)           Marcus Smart
# ..      ...                               ...                    ...
# 85       SF            Malik Fitts (23058863)            Malik Fitts
# 86       PF        Al-Farouq Aminu (23058864)        Al-Farouq Aminu
# 87       SF         Justin Jackson (23058865)         Justin Jackson
# 88       SF           Axel Toupane (23058866)           Axel Toupane
# 89        C  Juan Toscano-Anderson (23058867)  Juan Toscano-Anderson
#
#           ID Roster Position  Salary                      Game Info  \
# 0   23058778             CPT   17400  GSW@BOS 06/16/2022 09:00PM ET
# 1   23058779             CPT   16800  GSW@BOS 06/16/2022 09:00PM ET
# 2   23058780             CPT   14700  GSW@BOS 06/16/2022 09:00PM ET
# 3   23058781             CPT   12300  GSW@BOS 06/16/2022 09:00PM ET
# 4   23058782             CPT   12000  GSW@BOS 06/16/2022 09:00PM ET
# ..       ...             ...     ...                            ...
# 85  23058863            UTIL    1000  GSW@BOS 06/16/2022 09:00PM ET
# 86  23058864            UTIL    1000  GSW@BOS 06/16/2022 09:00PM ET
# 87  23058865            UTIL    1000  GSW@BOS 06/16/2022 09:00PM ET
# 88  23058866            UTIL    1000  GSW@BOS 06/16/2022 09:00PM ET
# 89  23058867            UTIL    1000  GSW@BOS 06/16/2022 09:00PM ET
#
#    TeamAbbrev  AvgPointsPerGame
# 0         GSW             45.97
# 1         BOS             47.47
# 2         BOS             39.47
# 3         GSW             30.48
# 4         BOS             30.11
# ..        ...               ...
# 85        BOS              2.62
# 86        BOS              0.00
# 87        BOS              3.96
# 88        GSW              0.00
# 89        GSW              9.85
#
# [90 rows x 9 columns]

# %%
# salary for players
UTIL = DKG_salary.loc[DKG_salary["Roster Position"] == "UTIL",:]

# %%
# salary for captains
CPT = DKG_salary.loc[DKG_salary["Roster Position"] == "CPT"]

# %%
#creates alt scores with avg ppg provided by draftkings
alt_scores = DKG_salary["AvgPointsPerGame"]

# %%
# makes new name list
new_names = nba_stats["Name"].tolist()

# %%
# change name to be compaitble with draftkings
new_names[27] = "Robert Williams"

nba_stats["Name"] = new_names

# %%
# iterates through UTIL to get salary
s = []
t = []
for x in nba_stats["Name"]:

    for row in UTIL.iterrows():
        if x == row[1]["Name"]:
            s.append(row[1]["Salary"])
            t.append(row[1]["AvgPointsPerGame"])

# %%
#makes column with salary
nba_stats["UTIL_salary"] = s

nba_stats["Alt_Salary"] = t

# %%
# gets CPT salary by 1.5 X UTIL
nba_stats["CPT_Salary"] = nba_stats["UTIL_salary"] * 1.5

# %%
# list of players to keep
name_list = ['Jayson Tatum',
 'Stephen Curry',
 'Jaylen Brown',
 'Al Horford',
 'Andrew Wiggins',
 'Klay Thompson',
 'Marcus Smart',
 'Draymond Green',
 'Jordan Poole',
 'Kevon Looney',
 'Derrick White', 
    'Gary Payton II',
            'Robert Williams']

# %%
# list of columns to drop 
drop_columns = [
 'Payton Pritchard',
 'Jonathan Kuminga',
 'Daniel Theis',
 'Nemanja Bjelica',
 'Damion Lee',
 'Moses Moody',
 'Juan Toscano-Anderson',
 'Aaron Nesmith',
 'Nik Stauskas',
 'Sam Hauser',
 'Juwan Morgan',
 'Luke Kornet',
 'Malik Fitts',
  'Andre Iguodala',
'Grant Williams',
'Otto Porter Jr.', 
]

# %%
index_drop = []
for i in drop_columns:
    row = nba_stats.loc[nba_stats["Name"] == i]
    index_drop.append(row.index[0])

# %%
for i in name_list:
    row = nba_stats.loc[nba_stats["Name"] == i]
    total_points = row["scores"]
    total_salary = 50000 - row["CPT_Salary"]

# %%
from itertools import combinations
total_lists = []
temp_chosen = []

for i in name_list:
    row = nba_stats.loc[nba_stats["Name"] == i]
    score = row["scores"].tolist()[0] * 1.5
    max_salary = 50000 - row["CPT_Salary"].tolist()[0]

    comb = nba_stats.drop(index = index_drop)
    comb = comb.sort_values("scores", ascending=False).copy()
    cpt_name = row["Name"].tolist()[0]
    print(cpt_name)
    print(score)
    temp_chosen.append({cpt_name : score})

    legit = ()
    max_score = 0

    comb = comb.drop(row.index)
    for combo in combinations(comb["Name"], 5):  # 2 for pairs, 3 for triplets, etc
        total_score = 0
        total_salary = 0
        for x in combo:
            rowP = nba_stats.loc[nba_stats["Name"] == x]
            total_score = total_score + rowP["scores"].tolist()[0]
            total_salary = total_salary + rowP["UTIL_salary"].tolist()[0]
        total_score = total_score + score
        if total_salary < max_salary:
            if total_score > max_score:
                team_salary = total_salary
                print(total_score)
                max_score = total_score
                legit = combo
                print(legit)
                
    temp_chosen.append({max_score : legit})
# Out:
# Jayson Tatum
# 77.40681818181818
# 215.20075757575756
# ('Andrew Wiggins', 'Klay Thompson', 'Gary Payton II', 'Robert Williams', 'Jordan Poole')
# 216.77348484848486
# ('Andrew Wiggins', 'Gary Payton II', 'Robert Williams', 'Al Horford', 'Draymond Green')
# Stephen Curry
# 70.60909090909091
# 205.62045454545455
# ('Andrew Wiggins', 'Klay Thompson', 'Gary Payton II', 'Al Horford', 'Jordan Poole')
# Jaylen Brown
# 54.25227272727271
# 195.42272727272723
# ('Jayson Tatum', 'Klay Thompson', 'Gary Payton II', 'Jordan Poole', 'Kevon Looney')
# 201.02348484848488
# ('Jayson Tatum', 'Gary Payton II', 'Robert Williams', 'Al Horford', 'Jordan Poole')
# Al Horford
# 35.502272727272725
# 205.6780303030303
# ('Jayson Tatum', 'Stephen Curry', 'Gary Payton II', 'Robert Williams', 'Jordan Poole')
# 206.84090909090907
# ('Jayson Tatum', 'Andrew Wiggins', 'Jaylen Brown', 'Gary Payton II', 'Jordan Poole')
# 207.2280303030303
# ('Jayson Tatum', 'Andrew Wiggins', 'Klay Thompson', 'Gary Payton II', 'Robert Williams')
# Andrew Wiggins
# 57.777272727272724
# 214.2659090909091
# ('Jayson Tatum', 'Jaylen Brown', 'Gary Payton II', 'Al Horford', 'Jordan Poole')
# 214.65303030303028
# ('Jayson Tatum', 'Klay Thompson', 'Gary Payton II', 'Robert Williams', 'Al Horford')
# Klay Thompson
# 41.66590909090908
# 211.63936896436894
# ('Jayson Tatum', 'Andrew Wiggins', 'Gary Payton II', 'Robert Williams', 'Marcus Smart')
# Marcus Smart
# 39.03746253746253
# 207.98064435564436
# ('Jayson Tatum', 'Andrew Wiggins', 'Klay Thompson', 'Gary Payton II', 'Al Horford')
# Draymond Green
# 35.031818181818174
# 202.42499999999998
# ('Jayson Tatum', 'Stephen Curry', 'Gary Payton II', 'Al Horford', 'Jordan Poole')
# 206.37045454545452
# ('Jayson Tatum', 'Andrew Wiggins', 'Jaylen Brown', 'Gary Payton II', 'Jordan Poole')
# 206.75757575757575
# ('Jayson Tatum', 'Andrew Wiggins', 'Klay Thompson', 'Gary Payton II', 'Robert Williams')
# Jordan Poole
# 26.509090909090908
# 206.66287878787878
# ('Jayson Tatum', 'Stephen Curry', 'Andrew Wiggins', 'Gary Payton II', 'Derrick White')
# 207.9522727272727
# ('Jayson Tatum', 'Andrew Wiggins', 'Jaylen Brown', 'Klay Thompson', 'Gary Payton II')
# Kevon Looney
# 25.11136363636364
# 196.61363636363637
# ('Jayson Tatum', 'Stephen Curry', 'Klay Thompson', 'Gary Payton II', 'Jordan Poole')
# 201.28257575757576
# ('Jayson Tatum', 'Stephen Curry', 'Gary Payton II', 'Robert Williams', 'Al Horford')
# 205.2280303030303
# ('Jayson Tatum', 'Andrew Wiggins', 'Jaylen Brown', 'Gary Payton II', 'Robert Williams')
# Derrick White
# 23.375
# 194.87727272727273
# ('Jayson Tatum', 'Stephen Curry', 'Klay Thompson', 'Gary Payton II', 'Jordan Poole')
# 199.5462121212121
# ('Jayson Tatum', 'Stephen Curry', 'Gary Payton II', 'Robert Williams', 'Al Horford')
# 203.49166666666665
# ('Jayson Tatum', 'Andrew Wiggins', 'Jaylen Brown', 'Gary Payton II', 'Robert Williams')
# Gary Payton II
# 41.062500000000014
# 222.3814393939394
# ('Jayson Tatum', 'Stephen Curry', 'Andrew Wiggins', 'Robert Williams', 'Jordan Poole')
# Robert Williams
# 39.67613636363636
# 207.06931818181818
# ('Jayson Tatum', 'Stephen Curry', 'Gary Payton II', 'Al Horford', 'Jordan Poole')
# 211.0147727272727
# ('Jayson Tatum', 'Andrew Wiggins', 'Jaylen Brown', 'Gary Payton II', 'Jordan Poole')

# %%
temp_chosen
# Out:
# [{'Jayson Tatum': 77.40681818181818},
#  {216.77348484848486: ('Andrew Wiggins',
#    'Gary Payton II',
#    'Robert Williams',
#    'Al Horford',
#    'Draymond Green')},
#  {'Stephen Curry': 70.60909090909091},
#  {205.62045454545455: ('Andrew Wiggins',
#    'Klay Thompson',
#    'Gary Payton II',
#    'Al Horford',
#    'Jordan Poole')},
#  {'Jaylen Brown': 54.25227272727271},
#  {201.02348484848488: ('Jayson Tatum',
#    'Gary Payton II',
#    'Robert Williams',
#    'Al Horford',
#    'Jordan Poole')},
#  {'Al Horford': 35.502272727272725},
#  {207.2280303030303: ('Jayson Tatum',
#    'Andrew Wiggins',
#    'Klay Thompson',
#    'Gary Payton II',
#    'Robert Williams')},
#  {'Andrew Wiggins': 57.777272727272724},
#  {214.65303030303028: ('Jayson Tatum',
#    'Klay Thompson',
#    'Gary Payton II',
#    'Robert Williams',
#    'Al Horford')},
#  {'Klay Thompson': 41.66590909090908},
#  {211.63936896436894: ('Jayson Tatum',
#    'Andrew Wiggins',
#    'Gary Payton II',
#    'Robert Williams',
#    'Marcus Smart')},
#  {'Marcus Smart': 39.03746253746253},
#  {207.98064435564436: ('Jayson Tatum',
#    'Andrew Wiggins',
#    'Klay Thompson',
#    'Gary Payton II',
#    'Al Horford')},
#  {'Draymond Green': 35.031818181818174},
#  {206.75757575757575: ('Jayson Tatum',
#    'Andrew Wiggins',
#    'Klay Thompson',
#    'Gary Payton II',
#    'Robert Williams')},
#  {'Jordan Poole': 26.509090909090908},
#  {207.9522727272727: ('Jayson Tatum',
#    'Andrew Wiggins',
#    'Jaylen Brown',
#    'Klay Thompson',
#    'Gary Payton II')},
#  {'Kevon Looney': 25.11136363636364},
#  {205.2280303030303: ('Jayson Tatum',
#    'Andrew Wiggins',
#    'Jaylen Brown',
#    'Gary Payton II',
#    'Robert Williams')},
#  {'Derrick White': 23.375},
#  {203.49166666666665: ('Jayson Tatum',
#    'Andrew Wiggins',
#    'Jaylen Brown',
#    'Gary Payton II',
#    'Robert Williams')},
#  {'Gary Payton II': 41.062500000000014},
#  {222.3814393939394: ('Jayson Tatum',
#    'Stephen Curry',
#    'Andrew Wiggins',
#    'Robert Williams',
#    'Jordan Poole')},
#  {'Robert Williams': 39.67613636363636},
#  {211.0147727272727: ('Jayson Tatum',
#    'Andrew Wiggins',
#    'Jaylen Brown',
#    'Gary Payton II',
#    'Jordan Poole')}]

# %%
total_lists = []
alt_chosen = []

for i in name_list:
    row = nba_stats.loc[nba_stats["Name"] == i]
    score = row["Alt_Salary"].tolist()[0] * 1.5
    max_salary = 50000 - row["CPT_Salary"].tolist()[0]

    comb = nba_stats.drop(index = index_drop)
    comb = comb.sort_values("Alt_Salary", ascending=False).copy()
    cpt_name = row["Name"].tolist()[0]
    print(cpt_name)
    alt_chosen.append({cpt_name : score})

    legit = ()
    max_score = 0

    comb = comb.drop(row.index)
    for combo in combinations(comb["Name"], 5):  # 2 for pairs, 3 for triplets, etc
        total_score = 0
        total_salary = 0
        for x in combo:
            rowP = nba_stats.loc[nba_stats["Name"] == x]
            total_score = total_score + rowP["Alt_Salary"].tolist()[0]
            total_salary = total_salary + rowP["UTIL_salary"].tolist()[0]
        total_score = total_score + score
        if total_salary < max_salary:
            if total_score > max_score:
                team_salary = total_salary
                print(total_score)
                max_score = total_score
                legit = combo
                print(legit)
                
    alt_chosen.append({max_score : legit})
# Out:
# Jayson Tatum
# 213.89499999999998
# ('Jaylen Brown', 'Jordan Poole', 'Al Horford', 'Derrick White', 'Gary Payton II')
# 221.03500000000003
# ('Klay Thompson', 'Jordan Poole', 'Al Horford', 'Draymond Green', 'Derrick White')
# Stephen Curry
# 211.64499999999998
# ('Jaylen Brown', 'Jordan Poole', 'Al Horford', 'Derrick White', 'Gary Payton II')
# 215.72500000000002
# ('Jordan Poole', 'Al Horford', 'Draymond Green', 'Robert Williams', 'Derrick White')
# Jaylen Brown
# 212.065
# ('Jayson Tatum', 'Klay Thompson', 'Jordan Poole', 'Derrick White', 'Gary Payton II')
# 213.825
# ('Jayson Tatum', 'Jordan Poole', 'Al Horford', 'Draymond Green', 'Gary Payton II')
# Al Horford
# 215.74
# ('Jayson Tatum', 'Stephen Curry', 'Jordan Poole', 'Draymond Green', 'Gary Payton II')
# 219.45
# ('Jayson Tatum', 'Jaylen Brown', 'Jordan Poole', 'Draymond Green', 'Derrick White')
# Andrew Wiggins
# 209.61
# ('Jayson Tatum', 'Jaylen Brown', 'Jordan Poole', 'Al Horford', 'Gary Payton II')
# 212.82000000000002
# ('Jayson Tatum', 'Klay Thompson', 'Jordan Poole', 'Al Horford', 'Derrick White')
# 213.69
# ('Jayson Tatum', 'Jordan Poole', 'Al Horford', 'Draymond Green', 'Robert Williams')
# Klay Thompson
# 212.59500000000003
# ('Jayson Tatum', 'Jaylen Brown', 'Jordan Poole', 'Al Horford', 'Gary Payton II')
# 213.815
# ('Jayson Tatum', 'Jordan Poole', 'Andrew Wiggins', 'Al Horford', 'Derrick White')
# 216.675
# ('Jayson Tatum', 'Jordan Poole', 'Al Horford', 'Draymond Green', 'Robert Williams')
# Marcus Smart
# 209.055
# ('Jayson Tatum', 'Jaylen Brown', 'Jordan Poole', 'Al Horford', 'Gary Payton II')
# 212.26500000000001
# ('Jayson Tatum', 'Klay Thompson', 'Jordan Poole', 'Al Horford', 'Derrick White')
# 213.135
# ('Jayson Tatum', 'Jordan Poole', 'Al Horford', 'Draymond Green', 'Robert Williams')
# Draymond Green
# 215.69
# ('Jayson Tatum', 'Stephen Curry', 'Jordan Poole', 'Al Horford', 'Gary Payton II')
# 219.40000000000003
# ('Jayson Tatum', 'Jaylen Brown', 'Jordan Poole', 'Al Horford', 'Derrick White')
# Jordan Poole
# 218.155
# ('Jayson Tatum', 'Stephen Curry', 'Klay Thompson', 'Al Horford', 'Gary Payton II')
# 221.865
# ('Jayson Tatum', 'Jaylen Brown', 'Klay Thompson', 'Al Horford', 'Derrick White')
# Kevon Looney
# 203.025
# ('Jayson Tatum', 'Stephen Curry', 'Klay Thompson', 'Jordan Poole', 'Gary Payton II')
# 206.735
# ('Jayson Tatum', 'Jaylen Brown', 'Klay Thompson', 'Jordan Poole', 'Derrick White')
# 208.495
# ('Jayson Tatum', 'Jaylen Brown', 'Jordan Poole', 'Al Horford', 'Draymond Green')
# Derrick White
# 211.965
# ('Jayson Tatum', 'Stephen Curry', 'Klay Thompson', 'Jordan Poole', 'Gary Payton II')
# 217.435
# ('Jayson Tatum', 'Jaylen Brown', 'Jordan Poole', 'Al Horford', 'Draymond Green')
# Gary Payton II
# 210.89000000000001
# ('Jayson Tatum', 'Stephen Curry', 'Klay Thompson', 'Jordan Poole', 'Al Horford')
# Robert Williams
# 214.50500000000002
# ('Jayson Tatum', 'Stephen Curry', 'Jordan Poole', 'Al Horford', 'Gary Payton II')
# 218.21500000000003
# ('Jayson Tatum', 'Jaylen Brown', 'Jordan Poole', 'Al Horford', 'Derrick White')

# %%
alt_chosen
# Out:
# [{'Jayson Tatum': 71.205},
#  {221.03500000000003: ('Klay Thompson',
#    'Jordan Poole',
#    'Al Horford',
#    'Draymond Green',
#    'Derrick White')},
#  {'Stephen Curry': 68.955},
#  {215.72500000000002: ('Jordan Poole',
#    'Al Horford',
#    'Draymond Green',
#    'Robert Williams',
#    'Derrick White')},
#  {'Jaylen Brown': 59.205},
#  {213.825: ('Jayson Tatum',
#    'Jordan Poole',
#    'Al Horford',
#    'Draymond Green',
#    'Gary Payton II')},
#  {'Al Horford': 45.45},
#  {219.45: ('Jayson Tatum',
#    'Jaylen Brown',
#    'Jordan Poole',
#    'Draymond Green',
#    'Derrick White')},
#  {'Andrew Wiggins': 45.72},
#  {213.69: ('Jayson Tatum',
#    'Jordan Poole',
#    'Al Horford',
#    'Draymond Green',
#    'Robert Williams')},
#  {'Klay Thompson': 48.705},
#  {216.675: ('Jayson Tatum',
#    'Jordan Poole',
#    'Al Horford',
#    'Draymond Green',
#    'Robert Williams')},
#  {'Marcus Smart': 45.165},
#  {213.135: ('Jayson Tatum',
#    'Jordan Poole',
#    'Al Horford',
#    'Draymond Green',
#    'Robert Williams')},
#  {'Draymond Green': 45.3},
#  {219.40000000000003: ('Jayson Tatum',
#    'Jaylen Brown',
#    'Jordan Poole',
#    'Al Horford',
#    'Derrick White')},
#  {'Jordan Poole': 45.885},
#  {221.865: ('Jayson Tatum',
#    'Jaylen Brown',
#    'Klay Thompson',
#    'Al Horford',
#    'Derrick White')},
#  {'Kevon Looney': 30.464999999999996},
#  {208.495: ('Jayson Tatum',
#    'Jaylen Brown',
#    'Jordan Poole',
#    'Al Horford',
#    'Draymond Green')},
#  {'Derrick White': 39.405},
#  {217.435: ('Jayson Tatum',
#    'Jaylen Brown',
#    'Jordan Poole',
#    'Al Horford',
#    'Draymond Green')},
#  {'Gary Payton II': 24.089999999999996},
#  {210.89000000000001: ('Jayson Tatum',
#    'Stephen Curry',
#    'Klay Thompson',
#    'Jordan Poole',
#    'Al Horford')},
#  {'Robert Williams': 44.115},
#  {218.21500000000003: ('Jayson Tatum',
#    'Jaylen Brown',
#    'Jordan Poole',
#    'Al Horford',
#    'Derrick White')}]
